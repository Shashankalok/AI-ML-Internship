# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\Desktop\vccodepy\.venv\Scripts\python.exe

# %%
import sys
# !{sys.executable} -m pip install groq

# %%
# !pip install groq

# %%
import groq
print("Working ")
# Out:
# Working

# %%
import os
os.environ["GROQ_API_KEY"] = "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"

# %%
# !pip install langchain-groq

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\Desktop\vccodepy\.venv\Scripts\python.exe

# %%
# !{sys.executable} -m pip install langchain-groq
# Out:
# ...
#   Using cached langchain_groq-1.1.2-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached langchain_core-1.2.27-py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langsmith-0.7.26-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached uuid_utils-0.14.1-cp39-abi3-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# ...
# Using cached langchain_groq-1.1.2-py3-none-any.whl (19 kB)
# Using cached groq-0.37.1-py3-none-any.whl (137 kB)
# Using cached langchain_core-1.2.27-py3-none-any.whl (508 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langsmith-0.7.26-py3-none-any.whl (360 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# ...

# %%
import os
from langchain_groq import ChatGroq

# Set API Key
os.environ["GROQ_API_KEY"] = "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"

# Initialize model
llm = ChatGroq(
    model="llama-3.1-8b-instant"
)

# Invoke model
response = llm.invoke("Explain langchain and statistics in simple words")

# Print output
print(response.content)
# Out:
# **What is LangChain?**
#
# LangChain is an open-source software library for building large language models (LLMs) and AI chatbots. It allows developers to create custom AI applications that can understand, generate, and interact with human language.
#
# Think of LangChain like a Lego box that gives you the building blocks to create your own AI chatbots, virtual assistants, or language-based applications. It provides a set of tools and APIs that make it easier to integrate LLMs into your projects.
#
# **Key Features of LangChain:**
#
# 1. **LLM Integration**: LangChain makes it easy to integrate LLMs into your applications, allowing you to leverage their language understanding and generation capabilities.
# 2. **Customizable**: LangChain provides a flexible framework for building custom AI applications, allowing you to tailor the AI to your specific needs.
# ...

# %%
llm.invoke("Explain langchain and statistics in simple words with examples")
# Out:
# AIMessage(content='**What is LangChain?**\n\nLangChain is a set of open-source tools and libraries used for building large language models (LLMs) and other natural language processing (NLP) applications. It\'s like a toolkit for developers to create their own AI chatbots, virtual assistants, or language translation systems.\n\nImagine you\'re trying to build a house. You would need a foundation, walls, a roof, and doors. LangChain provides the building blocks (foundation, walls, roof), but you need to assemble them to create your final product.\n\n**Key Features of LangChain:**\n\n1. **LLaMA**: LangChain uses the LLaMA model, a type of large language model developed by Meta AI.\n2. **Prompt Engineering**: LangChain allows you to craft custom prompts to interact with LLaMA and get specific answers.\n3. **Chain**: LangChain\'s "chain" feature enables you to create a sequence of tasks, like a workflow, to achieve a specific goal.\n\n**Statistics in Simple Words:**\n\nStatistics is a bra
# ...

# %%
# !pip install langchain

# %%
# !pip install langchain langchain-community langchain-groq

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\Desktop\vccodepy\.venv\Scripts\python.exe

# %%
# !{sys.executable} -m pip install langchain
# Out:
# ...
#   Using cached langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached langgraph-1.1.6-py3-none-any.whl.metadata (8.0 kB)
# ...
#   Using cached langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached langgraph_prebuilt-1.0.9-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# ...
# Using cached langchain-1.2.15-py3-none-any.whl (112 kB)
# Using cached langgraph-1.1.6-py3-none-any.whl (169 kB)
# Using cached langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Using cached langgraph_prebuilt-1.0.9-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# ...
#
#    ---------------------------------------- 0/6 [ormsgpack]
#    ------ --------------------------------- 1/6 [langgraph-sdk]
#    ------ --------------------------------- 1/6 [langgraph-sdk]
#    ------ --------------------------------- 1/6 [langgraph-sdk]
# ...

# %%
# !pip install langchain langchain-community langchain-groq

# %%
from langchain_core.prompts import PromptTemplate
from langchain_groq import ChatGroq

# Model
llm = ChatGroq(model="llama-3.1-8b-instant")

# Prompt template
prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple words with real-life examples"
)

# Format prompt
final_prompt = prompt.format(topic="langchain and probability")

# Run
response = llm.invoke(final_prompt)

print(response.content)
# Out:
# **Langchain:**
#
# Langchain is a technology that enables computers to understand, generate, and interact with human language. It's like a super-smart language assistant that can:
#
# 1. **Understand**: Langchain can read and comprehend human language, just like a human would.
# 2. **Generate**: Langchain can create new text, chat, or even entire stories based on what it's learned.
# 3. **Interact**: Langchain can have conversations with humans, answering questions, providing information, or even telling jokes.
#
# Think of Langchain like a magic typist that can:
#
# * Summarize a 10-page article into a 1-paragraph summary
# * Write a story based on a prompt (e.g., "write a story about a character who discovers a hidden treasure")
# * Answer questions on a wide range of topics
#
# **Probability:**
#
# Probability is a measure of how likely something is to happen. It's like a percentage chance of an event occurring.
#
# Imagine you flip a coin. Heads or tails?
#
# ...

# %%
from langchain_groq import ChatGroq
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# Model
llm = ChatGroq(model="llama-3.1-8b-instant")

# Memory store
store = {}

def get_session_history(session_id):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# Chain with memory
chain = RunnableWithMessageHistory(
    llm,
    get_session_history
)

# Conversation
response1 = chain.invoke(
    "Hi, my name is Shashank",
    config={"configurable": {"session_id": "1"}}
)

response2 = chain.invoke(
    "What is my name?",
    config={"configurable": {"session_id": "1"}}
)

print(response1.content)
print(response2.content)
# Out:
# Hello Shashank, it's nice to meet you. Is there something I can help you with or would you like to chat?
# Your name is Shashank.

# %%
from langchain_groq import ChatGroq
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# Model
llm = ChatGroq(model="llama-3.1-8b-instant")

# Memory store
store = {}

def get_session_history(session_id):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# Chatbot chain
chatbot = RunnableWithMessageHistory(
    llm,
    get_session_history
)

# Continuous chat loop
while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    response = chatbot.invoke(
        user_input,
        config={"configurable": {"session_id": "1"}}
    )

    print("AI:", response.content)
# Out:
# AI: I'm happy to chat with you, but I don't know your name. I'm a large language model, I don't have any prior knowledge about you, and our conversation just started. Would you like to introduce yourself?
# AI: You haven't shared your name with me yet. You said "my name" but didn't provide the actual name. If you're ready, I'd love to know your name!
# AI: Nice to meet you, Shashank! It's great that you've introduced yourself. Now that we've got that covered, how's your day going so far? Is there anything in particular you'd like to chat about or ask?
# AI: You've shared your name with me earlier, Shashank. Your name is Shashank.
# AI: Here are two short sentences about statistics:
#
# Statistics is a branch of mathematics that deals with the collection, analysis, interpretation, presentation, and organization of data. It provides a quantitative approach to understanding patterns and trends within data, allowing for informed decisions to be made.
# ...
